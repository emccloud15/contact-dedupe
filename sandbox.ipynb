# %%
from nicknames import name_triplets

names = name_triplets()
for name in names:
    if name.name1 == 'christina':
        print(name)
# Out:
# NameTriplet(name1='christina', relationship='has_nickname', name2='chris')
# NameTriplet(name1='christina', relationship='has_nickname', name2='chrissy')
# NameTriplet(name1='christina', relationship='has_nickname', name2='christy')
# NameTriplet(name1='christina', relationship='has_nickname', name2='crissy')
# NameTriplet(name1='christina', relationship='has_nickname', name2='kris')
# NameTriplet(name1='christina', relationship='has_nickname', name2='kristy')
# NameTriplet(name1='christina', relationship='has_nickname', name2='tina')

# %%
from nicknames import NickNamer

nn = NickNamer()

nicks = nn.nicknames_of("Tina")

print(nicks)
# Out:
# {'christina'}
